# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/Test_R5_DE/blob/main/POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.5.7)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 16.7 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.7 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.8 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.2 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 9.0 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=c2595c0efedee8190d5ba96c41b168916a678c6ad01a25a2d1c7647c95474271
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
from bs4 import BeautifulSoup
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import pandas as pd
import time,os,requests,nltk
from googletrans import Translator
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import sqlite3

# Download necessary resources from NLTK
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def fetch_news_headlines(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    headlines_data = []
    for article in soup.find_all('a', class_='Card-title'):
        headline = article.get_text(strip=True)
        soup_article = BeautifulSoup(str(article), 'html.parser')
        headline_url = soup_article.find('a', class_='Card-title')['href']
        timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())
        print(f'Fetching data for {headline[:25]}...')
        headlines_data.append({'headline': headline, 'url': headline_url, 'timestamp': timestamp})
    return headlines_data

def analyze_sentiment(headlines_data):
    sentiment_scores = []
    for headline_data in headlines_data:
        headline = headline_data['headline']
        blob = TextBlob(headline)
        sentiment_score = blob.sentiment.polarity
        sentiment_scores.append(sentiment_score)
    return sentiment_scores


def fetch_stock_data(api_key, symbol, time_series='TIME_SERIES_MONTHLY'):
    print(f'Fetching data for {symbol}')
    url = f'https://www.alphavantage.co/query?function={time_series}&symbol={symbol}&apikey={api_key}'
    response = requests.get(url)
    data = response.json()
    stock_data = pd.DataFrame(data['Monthly Time Series']).T
    stock_data.index = pd.to_datetime(stock_data.index)
    return stock_data

def translate_to_spanish(text):
    print(f'Translating {text[:25]}... to Spanish')
    return translator.translate(text, dest='es').text

def translate_to_italian(text):
    print(f'Translating {text[:25]}... to Italian')
    return translator.translate(text, dest='it').text

def extract_relevant_words(text):
    print(f'Extracting relevant words from {text[:25]}...')
    # Tokenize the text into individual words
    words = word_tokenize(text)
    # Remove stop words from the text
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if not word.lower() in stop_words]
    # Lemmatize the words to their base form
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    return words

def create_folder(folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    return folder_name

url = 'https://www.cnbc.com/stocks/'
api_key = 'SZLYEM0FZ8OIMCV3'
symbols = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META']

if __name__ == '__main__':

    print('-----------ETL Project-----------')
    translator = Translator()
    print('-----------CNBC Headlines-----------')
    headlines_data = fetch_news_headlines(url)
    sentiment_scores = analyze_sentiment(headlines_data)

    # Add sentiment scores to the headlines_data list of dictionaries
    for i, headline_data in enumerate(headlines_data):
        headline_data['sentiment_score'] = sentiment_scores[i]

    # Create a Pandas DataFrame from the headlines_data list of dictionaries
    headlines_df = pd.DataFrame(headlines_data)
    headlines_df['sentiment'] = headlines_df['sentiment_score'].apply(lambda x: 'positive' if x >= 0.2 else 'negative' if x <= -0.2 else 'neutral')
    headlines_df['relevant_words'] = headlines_df['headline'].apply(extract_relevant_words)
    # Create new translated columns
    headlines_df['headline_es'] = headlines_df['headline'].apply(translate_to_spanish)
    headlines_df['headline_it'] = headlines_df['headline'].apply(translate_to_italian)

    # Save the headlines DataFrame to a CSV file
    headlines_data_path = './data/headlines'
    headlines_df.to_csv(f'{create_folder(headlines_data_path)}/headlines_data.csv', index=False)

    print('-----------Stocks-----------')
    fetched_data_dfs = []
    for symbol in symbols:
        try:
            stock_data = pd.DataFrame(fetch_stock_data(api_key, symbol))
            stock_data['symbol'] = symbol
            fetched_data_dfs.append(stock_data)
        except Exception as e:
            print(f'Error fetching data for {symbol}, {e}')

    # Concatenate all the DataFrames into a single DataFrame
    stock_data_df = pd.concat(fetched_data_dfs, axis='rows', join='inner')
    stock_data_df = stock_data_df.reset_index()
    stock_data_df = stock_data_df.rename(columns={'index': 'date'})
    stock_data_df['date'] = pd.to_datetime(stock_data_df['date'])
    stock_data_df.rename(columns = {'1. open':'open_price','2. high':'highest_price','3. low':'lowest_price','4. close':'close_price','5. volume':'volume'},inplace=True)

    stocks_data_path = './data/stocks'
    stock_data_df.to_csv(f'{create_folder(stocks_data_path)}/stocks_data.csv', index=False)

#Load the data into a SQLLite database
print('Loading data into SQLite database')
try:
    conn = sqlite3.connect('etl_extended_case.db')
    c = conn.cursor()
    c.execute('CREATE TABLE IF NOT EXISTS headlines (headline TEXT, url TEXT, timestamp TEXT, sentiment_score REAL, sentiment TEXT, relevant_words TEXT, headline_es TEXT, headline_it TEXT)')
    c.execute('CREATE TABLE IF NOT EXISTS stocks (date TEXT, open_price REAL, highest_price REAL, lowest_price REAL, close_price REAL, volume REAL, symbol TEXT)')
    conn.commit()

    #Read the data from the CSV files and load into the SQLLite database
    headlines_df = pd.read_csv('./data/headlines/headlines_data.csv')
    stock_data_df = pd.read_csv('./data/stocks/stocks_data.csv')
    headlines_df.to_sql('headlines', conn, if_exists='replace', index=False)
    stock_data_df.to_sql('stocks', conn, if_exists='replace', index=False)
    conn.close()
    print('ETL Job has been completed successfully')
except Exception as e:
    print(f'Error loading data into SQLite database, {e}')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# -----------ETL Project-----------
# -----------CNBC Headlines-----------
# Fetching data for Nasdaq 100 index to under...
# Fetching data for Stocks making the biggest...
# Fetching data for Credit Suisse gives its t...
# Fetching data for JPMorgan's top equity gur...
# Fetching data for Buffett ups bet on energy...
# Fetching data for Stocks making the biggest...
# Fetching data for Bank of America names Ame...
# Fetching data for Goldman Sachs says T-Mobi...
# Fetching data for Piper Sandler upgrades Zi...
# Fetching data for Buy 'best-in-class' JPMor...
# Fetching data for Former CFTC chairman says...
# Fetching data for Cramer's Lightning Round:...
# Fetching data for China has a new foreign r...
# Fetching data for Jim Cramer says investors...
# Fetching data for Astra plans a reverse sto...
# Fetching data for Meta surges as 100M sign ...
# Fetching data for Morgan Stanley offers way...
# Fetching data for Earnings season is upon u...
# Fetching data for Stocks making the biggest...
# Fetching data for The CPI trade: What JPMor...
# Fetching data for How Amazon's Prime Day wi...
# Fetching data for Morgan Stanley upgrades t...
# Fetching data for Citi downgrades U.S. stoc...
# Fetching data for Stocks making the biggest...
# Fetching data for JPMorgan says buy this Me...
# Fetching data for Bank of America ups price...
# Fetching data for Goldman raises Nvidia pri...
# Fetching data for The chip wars are heating...
# Fetching data for Biogen falls after Alzhei...
# Fetching data for Refile and wait? Pulse ch...
# Fetching data for June inflation data will ...
# Fetching data for These stocks, plus Tesla,...
# Fetching data for Stocks making the biggest...
# Fetching data for We're not giving up on th...
# Fetching data for This international stock ...
# Extracting relevant words from Nasdaq 100 index to under...
# Extracting relevant words from Stocks making the biggest...
# Extracting relevant words from Credit Suisse gives its t...
# Extracting relevant words from JPMorgan's top equity gur...
# Extracting relevant words from Buffett ups bet on energy...
# Extracting relevant words from Stocks making the biggest...
# Extracting relevant words from Bank of America names Ame...
# Extracting relevant words from Goldman Sachs says T-Mobi...
# Extracting relevant words from Piper Sandler upgrades Zi...
# Extracting relevant words from Buy 'best-in-class' JPMor...
# Extracting relevant words from Former CFTC chairman says...
# Extracting relevant words from Cramer's Lightning Round:...
# Extracting relevant words from China has a new foreign r...
# Extracting relevant words from Jim Cramer says investors...
# Extracting relevant words from Astra plans a reverse sto...
# Extracting relevant words from Meta surges as 100M sign ...
# Extracting relevant words from Morgan Stanley offers way...
# Extracting relevant words from Earnings season is upon u...
# Extracting relevant words from Stocks making the biggest...
# Extracting relevant words from The CPI trade: What JPMor...
# Extracting relevant words from How Amazon's Prime Day wi...
# Extracting relevant words from Morgan Stanley upgrades t...
# Extracting relevant words from Citi downgrades U.S. stoc...
# Extracting relevant words from Stocks making the biggest...
# Extracting relevant words from JPMorgan says buy this Me...
# Extracting relevant words from Bank of America ups price...
# Extracting relevant words from Goldman raises Nvidia pri...
# Extracting relevant words from The chip wars are heating...
# Extracting relevant words from Biogen falls after Alzhei...
# Extracting relevant words from Refile and wait? Pulse ch...
# Extracting relevant words from June inflation data will ...
# Extracting relevant words from These stocks, plus Tesla,...
# Extracting relevant words from Stocks making the biggest...
# Extracting relevant words from We're not giving up on th...
# Extracting relevant words from This international stock ...
# Translating Nasdaq 100 index to under... to Spanish
# Translating Stocks making the biggest... to Spanish
# Translating Credit Suisse gives its t... to Spanish
# Translating JPMorgan's top equity gur... to Spanish
# Translating Buffett ups bet on energy... to Spanish
# Translating Stocks making the biggest... to Spanish
# Translating Bank of America names Ame... to Spanish
# Translating Goldman Sachs says T-Mobi... to Spanish
# Translating Piper Sandler upgrades Zi... to Spanish
# Translating Buy 'best-in-class' JPMor... to Spanish
# Translating Former CFTC chairman says... to Spanish
# Translating Cramer's Lightning Round:... to Spanish
# Translating China has a new foreign r... to Spanish
# Translating Jim Cramer says investors... to Spanish
# Translating Astra plans a reverse sto... to Spanish
# Translating Meta surges as 100M sign ... to Spanish
# Translating Morgan Stanley offers way... to Spanish
# Translating Earnings season is upon u... to Spanish
# Translating Stocks making the biggest... to Spanish
# Translating The CPI trade: What JPMor... to Spanish
# Translating How Amazon's Prime Day wi... to Spanish
# Translating Morgan Stanley upgrades t... to Spanish
# Translating Citi downgrades U.S. stoc... to Spanish
# Translating Stocks making the biggest... to Spanish
# Translating JPMorgan says buy this Me... to Spanish
# Translating Bank of America ups price... to Spanish
# Translating Goldman raises Nvidia pri... to Spanish
# Translating The chip wars are heating... to Spanish
# Translating Biogen falls after Alzhei... to Spanish
# Translating Refile and wait? Pulse ch... to Spanish
# Translating June inflation data will ... to Spanish
# Translating These stocks, plus Tesla,... to Spanish
# Translating Stocks making the biggest... to Spanish
# Translating We're not giving up on th... to Spanish
# Translating This international stock ... to Spanish
# Translating Nasdaq 100 index to under... to Italian
# Translating Stocks making the biggest... to Italian
# Translating Credit Suisse gives its t... to Italian
# Translating JPMorgan's top equity gur... to Italian
# Translating Buffett ups bet on energy... to Italian
# Translating Stocks making the biggest... to Italian
# Translating Bank of America names Ame... to Italian
# Translating Goldman Sachs says T-Mobi... to Italian
# Translating Piper Sandler upgrades Zi... to Italian
# Translating Buy 'best-in-class' JPMor... to Italian
# Translating Former CFTC chairman says... to Italian
# Translating Cramer's Lightning Round:... to Italian
# Translating China has a new foreign r... to Italian
# Translating Jim Cramer says investors... to Italian
# Translating Astra plans a reverse sto... to Italian
# Translating Meta surges as 100M sign ... to Italian
# Translating Morgan Stanley offers way... to Italian
# Translating Earnings season is upon u... to Italian
# Translating Stocks making the biggest... to Italian
# Translating The CPI trade: What JPMor... to Italian
# Translating How Amazon's Prime Day wi... to Italian
# Translating Morgan Stanley upgrades t... to Italian
# Translating Citi downgrades U.S. stoc... to Italian
# Translating Stocks making the biggest... to Italian
# Translating JPMorgan says buy this Me... to Italian
# Translating Bank of America ups price... to Italian
# Translating Goldman raises Nvidia pri... to Italian
# Translating The chip wars are heating... to Italian
# Translating Biogen falls after Alzhei... to Italian
# Translating Refile and wait? Pulse ch... to Italian
# Translating June inflation data will ... to Italian
# Translating These stocks, plus Tesla,... to Italian
# Translating Stocks making the biggest... to Italian
# Translating We're not giving up on th... to Italian
# Translating This international stock ... to Italian
# -----------Stocks-----------
# Fetching data for AAPL
# Fetching data for MSFT
# Fetching data for GOOGL
# Fetching data for AMZN
# Fetching data for META
# Loading data into SQLite database
# ETL Job has been completed successfully

# %%
# Conectarse a la base de datos SQLite
conn = sqlite3.connect('etl_extended_case.db')

# %%
# Ejecutar una consulta SQL utilizando Pandas
df = pd.read_sql_query("SELECT * FROM headlines", conn)
df
# Out:
#                                              headline  \
# 0   Nasdaq 100 index to undergo special rejiggerin...
# 1   Stocks making the biggest moves midday: Shutte...
# 2   Credit Suisse gives its top stock picks for th...
# 3   ['JPMorgan', "'s", 'top', 'equity', 'guru', 's...
# 4   ['Buffett', 'ups', 'bet', 'energy', 'infrastru...
# 5   ['Stocks', 'making', 'biggest', 'premarket', '...
# 6   ['Bank', 'America', 'name', 'American', 'Expre...
# 7   ['Goldman', 'Sachs', 'say', 'T-Mobile', 'top',...
# 8   ['Piper', 'Sandler', 'upgrade', 'Zillow', ',',...
# 9   ['Buy', "'best-in-class", "'", 'JPMorgan', 'th...
# 10  ['Former', 'CFTC', 'chairman', 'say', 'crypto'...
# 11  ['Cramer', "'s", 'Lightning', 'Round', ':', 'P...
# 12  ['China', 'new', 'foreign', 'relation', 'law',...
# 13  ['Jim', 'Cramer', 'say', 'investor', 'focus', ...
# 14  ['Astra', 'plan', 'reverse', 'stock', 'split',...
# 15  ['Meta', 'surge', '100M', 'sign', 'Threads', '...
# 16  ['Morgan', 'Stanley', 'offer', 'way', 'play', ...
# 17  ['Earnings', 'season', 'upon', 'u', '.', 'look...
# 18  ['Stocks', 'making', 'biggest', 'move', 'midda...
# 19  ['CPI', 'trade', ':', 'JPMorgan', 'see', 'mark...
# 20  ['Amazon', "'s", 'Prime', 'Day', 'go', 'possib...
# 21  ['Morgan', 'Stanley', 'upgrade', 'medical', 'd...
# 22  ['Citi', 'downgrade', 'U.S.', 'stock', ',', 's...
# 23  ['Stocks', 'making', 'biggest', 'premarket', '...
# 24  ['JPMorgan', 'say', 'buy', 'Mediterranean', 'c...
# 25  ['Bank', 'America', 'ups', 'price', 'target', ...
# 26  ['Goldman', 'raise', 'Nvidia', 'price', 'targe...
# 27  ['chip', 'war', 'heating', '.', 'Chinese', 'st...
# 28  ['Biogen', 'fall', 'Alzheimer', '’', 'drug', '...
# 29  ['Refile', 'wait', '?', 'Pulse', 'check', 'que...
# 30  ['June', 'inflation', 'data', 'closely', 'watc...
# 31  ['stock', ',', 'plus', 'Tesla', ',', 'week', "...
# 32  ['Stocks', 'making', 'biggest', 'move', 'midda...
# 33  ["'re", 'giving', 'struggling', 'entertainment...
# 34  ['international', 'stock', 'pro', 'outpaces', ...
#
#                                           headline_es  \
# 0   El índice Nasdaq 100 se someterá a un reajuste...
# 1   Acciones que hacen los mayores movimientos al ...
# 2   Credit Suisse da sus mejores selecciones de ac...
# 3   El principal gurú de acciones de JPMorgan dice...
# 4   Buffett apuesta por las infraestructuras energ...
# 5   Acciones que realizan los mayores movimientos ...
# 6   Bank of America nombra a American Express como...
# 7   Goldman Sachs dice que T-Mobile es una de las ...
# 8   Piper Sandler actualiza Zillow, ve que las acc...
# 9   Compre JPMorgan 'mejor en su clase' gracias al...
# 10  El expresidente de la CFTC dice que las cripto...
# 11  Ronda relámpago de Cramer: Palantir es una compra
# 12  China tiene una nueva ley de relaciones exteri...
# 13  Jim Cramer dice que los inversores deberían ce...
# 14  Astra planea una división inversa de acciones,...
# 15  Meta surge cuando 100 millones se registran en...
# 16  Morgan Stanley ofrece formas de jugar A.I. a m...
# 17  La temporada de ganancias está sobre nosotros....
# 18  Acciones que hacen los mayores movimientos al ...
# 19  El comercio de IPC: lo que JPMorgan ve que hac...
# 20  Cómo irá el Prime Day de Amazon y la posible r...
# 21  Morgan Stanley mejora este fabricante de dispo...
# 22  Citi rebaja la calificación de las acciones de...
# 23  Acciones que realizan los mayores movimientos ...
# 24  JPMorgan dice comprar esta cadena mediterránea...
# 25  Bank of America sube el precio objetivo de est...
# 26  Goldman eleva el precio objetivo de Nvidia, di...
# 27  Las guerras de chips se están calentando. Esta...
# 28  Biogen cae tras la aprobación del fármaco cont...
# 29  ¿Volver a presentar y esperar? Control de puls...
# 30  Los inversores seguirán de cerca los datos de ...
# 31  Estas acciones, más Tesla, son las de mejor de...
# 32  Acciones que realizan los mayores movimientos ...
# 33  No nos vamos a dar por vencidos con esta acció...
# 34  Este profesional bursátil internacional supera...
#
#                                           headline_it
# 0   L'indice Nasdaq 100 subirà un rejigger special...
# 1   Le azioni che fanno le mosse più grandi a mezz...
# 2   Credit Suisse offre le sue migliori scelte di ...
# 3   Il principale guru azionario di JPMorgan affer...
# 4      Buffett punta sulle infrastrutture energetiche
# 5   Le azioni che effettuano le maggiori mosse pre...
# 6   Bank of America nomina American Express una de...
# 7   Goldman Sachs afferma che T-Mobile è la scelta...
# 8   Piper Sandler aggiorna Zillow, vede un rally d...
# 9   Acquista JPMorgan "best-in-class" grazie al fo...
# 10  L'ex presidente della CFTC afferma che i regol...
# 11   Cramer's Lightning Round: Palantir è un acquisto
# 12  La Cina ha una nuova legge sulle relazioni est...
# 13  Jim Cramer afferma che gli investitori dovrebb...
# 14  Astra pianifica un frazionamento azionario, ce...
# 15  Meta aumenta quando 100 milioni si iscrivono a...
# 16  Morgan Stanley offre modi per giocare a A.I. m...
# 17  La stagione degli utili è alle porte. A cosa p...
# 18  Azioni che fanno le mosse più grandi a mezzogi...
# 19  Il commercio CPI: cosa JPMorgan vede fare il m...
# 20  Come andrà il Prime Day di Amazon e la possibi...
# 21  Morgan Stanley aggiorna questo produttore di d...
# 22  Citi declassa le azioni statunitensi, vede l'S...
# 23  Le azioni che effettuano le maggiori mosse pre...
# 24  JPMorgan afferma di acquistare questa catena m...
# 25  La Bank of America alza l'obiettivo di prezzo ...
# 26  Goldman alza l'obiettivo di prezzo di Nvidia, ...
# 27  La guerra dei chip si sta surriscaldando. Ques...
# 28  Biogen cade dopo l'approvazione del farmaco pe...
# 29  Refile e aspettare? Controllo del polso sulla ...
# 30  I dati sull'inflazione di giugno saranno atten...
# 31  Questi titoli, più Tesla, sono i migliori di q...
# 32  Azioni che fanno le mosse più grandi a mezzogi...
# 33  Non ci arrendiamo con questo titolo di intratt...
# 34  Questo professionista azionario internazionale...
